# %%
import pandas as pd
import numpy as np
import os
import shutil
from sklearn.model_selection import train_test_split

# --- 1. Caminhos dos arquivos de entrada ---
OASIS_CSV = '../database/oasis_longitudinal_demographic.csv'
FEATURES_CSV = '../database/features_full.csv'
IDENTIFIERS_CSV = '../database/features_identifiers.csv'

# Diretório onde as imagens .nii originais estão
SOURCE_IMG_DIR = '../database/axl'

# --- 2. Caminhos de saída ---
TREINO_DIR = '../database/treino'
VAL_DIR = '../database/validacao'
TESTE_DIR = '../database/teste'

TREINO_IMG_DIR = os.path.join(TREINO_DIR, 'imgs')
VAL_IMG_DIR = os.path.join(VAL_DIR, 'imgs')
TESTE_IMG_DIR = os.path.join(TESTE_DIR, 'imgs')

# --- 3. Parâmetros da Divisão ---
TEST_SIZE = 0.20 # 20% para Teste
VAL_SIZE = 0.20 # 20% *do conjunto de treino* vai para Validação
RANDOM_STATE = 42

# Cria os diretórios de saída
os.makedirs(TREINO_IMG_DIR, exist_ok=True)
os.makedirs(VAL_IMG_DIR, exist_ok=True)
os.makedirs(TESTE_IMG_DIR, exist_ok=True)
print(f"Pastas de saída verificadas/criadas.")
print(f"  Treino: {TREINO_IMG_DIR}")
print(f"  Validação: {VAL_IMG_DIR}")
print(f"  Teste: {TESTE_IMG_DIR}")
# Out:
# Pastas de saída verificadas/criadas.
#   Treino: ../database/treino/imgs
#   Validação: ../database/validacao/imgs
#   Teste: ../database/teste/imgs

# %%
print("\n--- Processando oasis_longitudinal_demographic.csv ---")
try:
    # Usa decimal=',' para ler corretamente os floats (ex: 0,5)
    df_oasis = pd.read_csv(OASIS_CSV, sep=';', decimal=',')
    print(f"Forma original df_oasis: {df_oasis.shape}")
except FileNotFoundError:
    print(f"Erro: Arquivo {OASIS_CSV} não encontrado.")
    raise

# Função para mapear 'Converted' baseado no CDR
def map_class(row):
    if row['Group'] == 'Converted':
        if row['CDR'] > 0:
            return 'Demented'
        else: # Inclui CDR = 0 e CDR = NaN
            return 'NonDemented'
    return row['Group'] # Retorna 'Demented' ou 'NonDemented'

# Aplica a função para criar a classe final
df_oasis['Group'] = df_oasis.apply(map_class, axis=1)

# Filtra o dataframe para conter apenas as duas classes finais
df_oasis = df_oasis[df_oasis['Group'].isin(['Demented', 'NonDemented'])].copy()
print(f"Valores finais em 'Group': {df_oasis['Group'].unique()}")
print(f"Forma final df_oasis: {df_oasis.shape}")
# Out:
# --- Processando oasis_longitudinal_demographic.csv ---
# Forma original df_oasis: (373, 15)
# Valores finais em 'Group': ['Demented' 'NonDemented']
# Forma final df_oasis: (183, 15)

# %%
try:
    df_oasis = pd.read_csv(OASIS_CSV, sep=';', decimal=',')
except FileNotFoundError:
    print(f"Erro: Arquivo {OASIS_CSV} não encontrado.")
    raise

# Verifica a forma original e os valores
print(f"Forma original df_oasis: {df_oasis.shape}")
print(f"Valores originais em 'Group': {df_oasis['Group'].unique()}")

# Função map_class robusta que trata todos os casos, incluindo NaNs.
def map_class_robusta(row):
    group = row['Group']
    cdr = row['CDR']
    
    if group == 'Converted':
        if cdr > 0:
            return 'Demented'
        else: # Inclui CDR = 0 e CDR = NaN (que falha no > 0)
            return 'NonDemented'
    
    if group == 'Demented':
        return 'Demented'
    
    # Todos os outros casos ('Nondemented', NaN, etc.)
    # serão mapeados para 'NonDemented'.
    return 'NonDemented'

# Aplica a função robusta para criar a classe final
df_oasis['Group'] = df_oasis.apply(map_class_robusta, axis=1)

print(f"Valores finais em 'Group' (após mapeamento): {df_oasis['Group'].unique()}")
print(f"Forma final df_oasis (deve ser 373): {df_oasis.shape}")

if df_oasis.shape[0] != 373:
     print("ALERTA: O número de linhas mudou. Verifique a lógica.")
else:
     print("Processamento manteve todas as 373 visitas.")
# Out:
# Forma original df_oasis: (373, 15)
# Valores originais em 'Group': ['Nondemented' 'Demented' 'Converted']
# Valores finais em 'Group' (após mapeamento): ['NonDemented' 'Demented']
# Forma final df_oasis (deve ser 373): (373, 15)
# Processamento manteve todas as 373 visitas.

# %%
# --- Definir Rótulo Único por Paciente ---
print("\n--- Agrupando rótulos por paciente ---")

# Mapeia Demented=1, NonDemented=0
# (A Célula 3 já deve ter criado a coluna 'Group')
df_oasis['Group_num'] = df_oasis['Group'].map({'Demented': 1, 'NonDemented': 0})

# Agrupa por paciente (Subject ID) e pega o valor máximo
# Se um paciente teve UMA visita 'Demented' (1), ele será 'Demented' (1)
patient_labels = df_oasis.groupby('Subject ID')['Group_num'].max()

# Remove pacientes que possam ter tido apenas visitas com NaN (se houver)
patient_labels = patient_labels.dropna()

print(f"Total de pacientes únicos para divisão: {len(patient_labels)}")
print("Contagem de pacientes por classe (para estratificação):")
print(patient_labels.value_counts())
# Out:
# --- Agrupando rótulos por paciente ---
# Total de pacientes únicos para divisão: 150
# Contagem de pacientes por classe (para estratificação):
# Group_num
# 1    78
# 0    72
# Name: count, dtype: int64

# %%
print("\n--- Dividindo pacientes em Treino, Validação e Teste ---")

# Obtém a lista de pacientes (índice) e os rótulos (valores)
patient_ids = patient_labels.index
labels = patient_labels.values

# Separar Teste (20% do total)
train_val_patients, test_patients, train_val_labels, _ = train_test_split(
    patient_ids,
    labels,
    test_size=TEST_SIZE, # 0.20
    stratify=labels,
    random_state=RANDOM_STATE
)

# Separar Treino e Validação (do conjunto train_val de 80%)
# VAL_SIZE (0.20) será 20% do conjunto train_val_patients
# (Total de 0.8 * 0.2 = 0.16)
train_patients, val_patients, _, _ = train_test_split(
    train_val_patients,
    train_val_labels,
    test_size=VAL_SIZE, # 0.20
    stratify=train_val_labels,
    random_state=RANDOM_STATE # Usar o mesmo estado garante divisão consistente
)

print(f"Total de pacientes de TREINO: {len(train_patients)} (~{len(train_patients)/len(patient_ids):.0%})")
print(f"Total de pacientes de VALIDAÇÃO: {len(val_patients)} (~{len(val_patients)/len(patient_ids):.0%})")
print(f"Total de pacientes de TESTE: {len(test_patients)} (~{len(test_patients)/len(patient_ids):.0%})")
# Out:
# --- Dividindo pacientes em Treino, Validação e Teste ---
# Total de pacientes de TREINO: 96 (~64%)
# Total de pacientes de VALIDAÇÃO: 24 (~16%)
# Total de pacientes de TESTE: 30 (~20%)

# %%
# (Início da Célula 12)
print("\n--- Processando e salvando CSVs dos conjuntos ---")
try:
    # (O df_feat carregado aqui será o minimal_features_full.csv salvo pelo feature_extraction.ipynb)
    df_feat = pd.read_csv(FEATURES_CSV, sep=';', decimal=',')
    df_ids = pd.read_csv(IDENTIFIERS_CSV, sep=';', decimal=',')
except FileNotFoundError:
    print(f"Erro: Arquivos {FEATURES_CSV} ou {IDENTIFIERS_CSV} não encontrados.")
    raise

# Função auxiliar para filtrar e salvar os 3 CSVs
def save_datasets(patient_list, output_dir_base):
    """
    Filtra todos os 3 dataframes pela lista de pacientes, ATUALIZA A COLUNA
    'Group' e salva os CSVs.
    Retorna a lista de MRI IDs filtrados (para cópia de imagens).
    """
    print(f"\n  Processando diretório: {output_dir_base}")
    
    # 1. Filtrar df_oasis (já está limpo, com 'Group' corrigido na Célula 8)
    df_oasis_set = df_oasis[df_oasis['Subject ID'].isin(patient_list)]
    
    # 2. Obter os MRI IDs (exames) únicos deste conjunto de pacientes
    mr_ids_set = df_oasis_set['MRI ID'].unique()
    print(f"    Pacientes: {len(patient_list)}, Exames (MRI IDs): {len(mr_ids_set)}")

    # 3. Criar um mapa com os rótulos 'MRI ID' -> 'Group'
    #    Usamos o df_oasis_set que já foi limpo e filtrado.
    label_map = df_oasis_set.set_index('MRI ID')['Group']

    # 4. Filtrar df_ids e df_feat usando os MRI IDs
    #    Usamos .copy() para evitar "SettingWithCopyWarning"
    df_ids_set = df_ids[df_ids['MRI ID'].isin(mr_ids_set)].copy()
    df_feat_set = df_feat[df_feat['MRI ID'].isin(mr_ids_set)].copy()

    # 5. Atualizar a coluna 'Group' no df_ids_set
    if 'Group' in df_ids_set.columns:
        df_ids_set['Group'] = df_ids_set['MRI ID'].map(label_map)
        print(f"    Coluna 'Group' em features_identifiers.csv foi atualizada.")

    # 6. Atualizar a coluna 'Group' no df_feat_set (features_full)
    if 'Group' in df_feat_set.columns:
        df_feat_set['Group'] = df_feat_set['MRI ID'].map(label_map)
        print(f"    Coluna 'Group' em features_full.csv foi atualizada.")

    # 7. Salvar os CSVs
    try:
        # Salva com vírgula decimal para consistência
        df_oasis_set.to_csv(os.path.join(output_dir_base, 'oasis_longitudinal_demographic.csv'), index=False, sep=';', decimal=',')
        df_ids_set.to_csv(os.path.join(output_dir_base, 'features_identifiers.csv'), index=False, sep=';', decimal=',')
        df_feat_set.to_csv(os.path.join(output_dir_base, 'features_full.csv'), index=False, sep=';', decimal=',') # Salva o df_feat_set (agora limpo)
        print(f"    CSVs salvos com sucesso em {output_dir_base}")
        return mr_ids_set # Retorna os IDs para a cópia de imagens
    except Exception as e:
        print(f"    Erro ao salvar CSVs em {output_dir_base}: {e}")
        return []

# Salvar os 3 conjuntos (Restante da célula 12)
mr_ids_treino = save_datasets(train_patients, TREINO_DIR)
mr_ids_val = save_datasets(val_patients, VAL_DIR)
mr_ids_teste = save_datasets(test_patients, TESTE_DIR)
# Out:
# --- Processando e salvando CSVs dos conjuntos ---
#
#   Processando diretório: ../database/treino
#     Pacientes: 96, Exames (MRI IDs): 239
#     Coluna 'Group' em features_identifiers.csv foi atualizada.
#     Coluna 'Group' em features_full.csv foi atualizada.
#     CSVs salvos com sucesso em ../database/treino
#
#   Processando diretório: ../database/validacao
#     Pacientes: 24, Exames (MRI IDs): 58
#     Coluna 'Group' em features_identifiers.csv foi atualizada.
#     Coluna 'Group' em features_full.csv foi atualizada.
#     CSVs salvos com sucesso em ../database/validacao
#
#   Processando diretório: ../database/teste
#     Pacientes: 30, Exames (MRI IDs): 76
#     Coluna 'Group' em features_identifiers.csv foi atualizada.
#     Coluna 'Group' em features_full.csv foi atualizada.
#     CSVs salvos com sucesso em ../database/teste

# %%
print("\n--- Processando e copiando imagens (.nii) ---")

def copy_image_files(mr_ids_set, destination_img_dir):
    """
    Encontra e copia os arquivos .nii/.nii.gz baseado na lista de MRI IDs.
    """
    print(f"\n  Copiando imagens para: {destination_img_dir}")
    
    if not os.path.exists(SOURCE_IMG_DIR):
        print(f"    ALERTA: Diretório de origem das imagens não encontrado: {SOURCE_IMG_DIR}")
        print("    Nenhuma imagem será copiada. Ajuste a variável 'SOURCE_IMG_DIR'.")
        return

    # Lista de todos os arquivos de imagem de origem
    try:
        source_files = [f for f in os.listdir(SOURCE_IMG_DIR) if f.endswith(('.nii', '.nii.gz'))]
    except Exception as e:
        print(f"    Erro ao listar arquivos em {SOURCE_IMG_DIR}: {e}")
        return
        
    copied_count = 0
    missing_count = 0
    
    # Itera sobre os MR IDs que precisamos
    for mr_id in mr_ids_set:
        found_file = None
        # Procura o arquivo de origem que contém o MR ID
        for fname in source_files:
            if mr_id in fname:
                found_file = fname
                break # Encontrou o arquivo para este MR ID
        
        if found_file:
            source_path = os.path.join(SOURCE_IMG_DIR, found_file)
            dest_path = os.path.join(destination_img_dir, found_file)
            
            if not os.path.exists(dest_path): # Evita copiar se já existir
                try:
                    shutil.copy(source_path, dest_path)
                    copied_count += 1
                except Exception as e:
                    print(f"    Erro ao copiar {source_path}: {e}")
            else:
                copied_count += 1 # Conta como 'verificado' se já estiver lá
        else:
            print(f"    Aviso: Imagem para MRI ID {mr_id} não encontrada em {SOURCE_IMG_DIR}")
            missing_count += 1
            
    print(f"    Copiadas/Verificadas: {copied_count} imagens.")
    print(f"    Não encontradas: {missing_count} imagens.")

# Copiar imagens para os 3 conjuntos
copy_image_files(mr_ids_treino, TREINO_IMG_DIR)
copy_image_files(mr_ids_val, VAL_IMG_DIR)
copy_image_files(mr_ids_teste, TESTE_IMG_DIR)
# Out:
# --- Processando e copiando imagens (.nii) ---
#
#   Copiando imagens para: ../database/treino/imgs
#     Copiadas/Verificadas: 239 imagens.
#     Não encontradas: 0 imagens.
#
#   Copiando imagens para: ../database/validacao/imgs
#     Copiadas/Verificadas: 58 imagens.
#     Não encontradas: 0 imagens.
#
#   Copiando imagens para: ../database/teste/imgs
#     Copiadas/Verificadas: 76 imagens.
#     Não encontradas: 0 imagens.

# %%
print("\n--- Processamento Concluído ---")
print("Divisão Treino/Validação/Teste concluída.")
print("Verifique as pastas './database/treino', './database/validacao' e './database/teste'.")
# Out:
# --- Processamento Concluído ---
# Divisão Treino/Validação/Teste concluída.
# Verifique as pastas './database/treino', './database/validacao' e './database/teste'.
